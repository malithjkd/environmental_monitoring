# %%
#test
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_parth = "/home/malithjkd/Documents/20240211.txt"
data = pd.read_csv(file_parth)

data
# Out:
#      year  Month  Day  Hour  Min  Temparature  Humidity
# 0    2024      2   11     0    0         28.0      84.5
# 1    2024      2   11     0    1         27.9      85.0
# 2    2024      2   11     0    2         28.0      84.4
# 3    2024      2   11     0    3         28.0      84.8
# 4    2024      2   11     0    4         28.1      83.9
# ..    ...    ...  ...   ...  ...          ...       ...
# 900  2024      2   11    16   34         29.4      70.0
# 901  2024      2   11    16   35         29.5      70.0
# 902  2024      2   11    16   36         29.5      70.0
# 903  2024      2   11    16   37         29.4      70.2
# 904  2024      2   11    16   38         29.4      70.3
#
# [905 rows x 7 columns]

# %%
temp_float = data['Temparature'].astype(float)
humidity_float = data['Humidity'].astype(float)

# %%
plt.plot(temp_float)
plt.show()

# %%
plt.plot(humidity_float)
plt.show()
